# %% [markdown]
# # Test of PSG for Mars

# %%
#standard packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bokeh.plotting import figure,show
from bokeh.io import output_notebook

# %%
#custom packages
import OD
from utils import read_out

# %%
df_001 = read_out('../data/lyo/CO2_0_0_0.01_lyo.txt')
df_00001 = read_out('../data/lyo/CO2_0_0_0.0001_lyo.txt')

# %%
df_lr = OD.OD_compute(df_001)
df_hr = OD.OD_compute(df_00001)

# %%
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ea368187-2567-41ff-941c-42ff8354928d">Loading BokehJS ...</span>
#     </div>

# %%
df_bin = OD.OD_binning(df_hr,df_lr)

# %%
p = figure(x_axis_label = 'Frequency [cm-1]', y_axis_label = 'OD', width=800, height = 300, y_axis_type='log', title = 'OD CO2')
p.line(df_hr.freq,df_hr.level_25, line_alpha = 0.5, legend_label = 'high resolution OD', line_color='green', width = 2)
p.scatter(df_lr.freq,df_lr.level_25, marker = 'cross', size = 10, line_color='red', legend_label = 'low resolution OD (from PSG)')
p.scatter(df_bin.freq,df_bin.level_25, marker = 'dot', size = 15, line_color='blue', legend_label = 'high resolution binned OD')
show(p)
# Out:
#   <div id="b32f2105-d333-441f-9c9d-06bb6b587834" data-root-id="p1798" style="display: contents;"></div>

# %%
df_vez = OD.vez_bin(df_hr,df_lr)
df_vez2 = OD.vez_bin(df_hr,df_mr)
# Out:
# /Users/Lorenzo/Documents/Dottorato/PSG/PSG4Mars/python/OD.py:56: RuntimeWarning: invalid value encountered in scalar divide
#   buf = np.mean(c_tr[i,ind])/tt[i+1,j]

# %%
p = figure(x_axis_label = 'Frequency [cm-1]', y_axis_label = 'OD', width=1000, height = 500, y_axis_type='log')
p.line(df_hr.freq,df_hr.level_15, line_alpha = 0.5, legend_label = 'high res', line_color='green')
p.scatter(df_lr.freq,df_lr.level_15, marker = 'cross', size = 10, line_color='red', legend_label = 'low res')
p.scatter(df_vez.freq,df_vez.level_15, marker = 'dot', size = 10, line_color='blue', legend_label = 'binned')
show(p)
# Out:
#   <div id="b36b9f9f-a724-4195-b1dc-660de0855d36" data-root-id="p1871" style="display: contents;"></div>
